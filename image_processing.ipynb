# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
img = Image.open("shin.jpg")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=539x301 at 0x233D3DCE700>

# %%
arr = np.array(img)

# %%
arr.shape
# Out:
# (301, 539, 3)

# %%
cut = arr[10:250,150:400]

# %%
plt.imshow(cut)

# %%
img2 = Image.open("rgb.jpg")
img2
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=248x166 at 0x233DBDF6520>

# %%
arr2 = np.array(img2)

# %%
arr2.shape
# Out:
# (166, 248, 3)

# %%
red = arr2[:160,:180,:]#3rd argument in the list gives the colors like(0=red,1=green,2=blue)
# above code removes the colour.

# %%
plt.imshow(red)

# %%
work = arr.copy()

# %%
work[:,:,0]=1

# %%
plt.imshow(work)

# %%
gry = cut.mean(axis=2)

# %%
plt.imshow(gry,cmap="gray")
